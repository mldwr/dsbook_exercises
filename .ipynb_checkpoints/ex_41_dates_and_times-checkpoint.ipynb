# %% [markdown]
# ## Exercises

# %% [markdown]
# >In the previous exercise section, we wrangled data from a PDF file containing vital statistics from Puerto Rico. We did this for the month of September. Below we include code that does it for all 12 months.

# %%
library(tidyverse)
library(purrr)
library(pdftools)
library(lubridate)

# %%
fn <- system.file("extdata", "RD-Mortality-Report_2015-18-180531.pdf", package="dslabs")

# %%
tab <- map_df(str_split(pdf_text(fn), "\n"), function(s){
  s <- str_trim(s)
  header_index <- str_which(s, "2015")[1]
  tmp <- str_split(s[header_index], "\\s+", simplify = TRUE)
  month <- tmp[1]
  header <- tmp[-1]
  tail_index  <- str_which(s, "Total")
  n <- str_count(s, "\\d+")
  out <- c(1:header_index, which(n==1), which(n>=28), tail_index:length(s))
  s[-out] %>%
    str_remove_all("[^\\d\\s]") %>%
    str_trim() %>%
    str_split_fixed("\\s+", n = 6) %>%
    .[,1:5] %>%
    as_data_frame() %>% 
    setNames(c("day", header)) %>%
    mutate(month = month,day = as.numeric(day)) %>%
    gather(year, deaths, -c(day, month)) %>%
    mutate(deaths = as.numeric(deaths))
})

# %% [markdown]
# >1. We want to make a plot of death counts versus date. A first step is to convert the month variable from characters to numbers. Note that the month abbreviations are in Spanglish. Use the `recode` function to convert months to numbers and redefine `tab`.

# %%
tab <- tab %>% mutate(month = recode(month, 'JAN' = 01,'FEB' = 02,'MAR' = 03,'APR' = 04,'MAY' = 05,'JUN' = 06,'JUL' = 07,'AUG' = 08,'AGO' = 08,'SEP' = 09,'OCT' = 10,'NOV' = 11,'DEC' = 12,))

# %%
tab %>% filter(year==2017) %>% group_by(month) %>% summarize(n())
# Out:
#    month n()
# 1   1    31
# 2   2    29
# 3   3    31
# 4   4    30
# 5   5    31
# 6   6    30
# 7   7    31
# 8   8    31
# 9   9    29
# 10 10    30
# 11 11    29
# 12 12    30

# %%
tab %>% filter(year!=2018) %>% ggplot(aes(month,deaths,col=year)) + geom_point()
# Out:
# Warning message:
# “Removed 2 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# The plot throws a warning message which indicates missing values in the column "deaths".
# *"Warning message: Removed 2 rows containing missing values (geom_point)."*
# The missing values can be identified with the following code

# %%
tab[which(tab$deaths %in% NA),]
# Out:
#   day month year deaths
# 1 29  2     2016 NA
# 2 29  2     2017 NA
# 3 29  2     2018 NA

# %%
tab <- tab[-which(tab$deaths %in% NA),]

# %%
tab %>% filter(year!=2018) %>% ggplot(aes(month,deaths,col=year)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# >2. Create a new column `date` with the date for each observation. Hint: use the `make_date` function.

# %%
tab <- tab %>% mutate(date = make_date(year,month,day))

# %%
tab[which(tab$date %in% NA),]
# Out:
#   day month year deaths date
# 1 29  2     2015 70     <NA>

# %% [markdown]
# >3. Plot deaths versus date.

# %%
tab %>% filter(year!=2018) %>% ggplot(aes(date,deaths)) + geom_point()
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# >4. Note that after May 31, 2018, the deaths are all 0. The data is probably not entered yet. We also see a drop off starting around May 1. Redefine `tab` to exclude observations taken on or after May 1, 2018. Then, remake the plot.

# %%
tab %>% filter(year==2018) %>% group_by(month,year) %>% summarise(sum(deaths))
# Out:
#    month year sum(deaths)
# 1   1    2018 2821
# 2   2    2018 2448
# 3   3    2018 2643
# 4   4    2018 2218
# 5   5    2018 1892
# 6   6    2018    0
# 7   7    2018    0
# 8   8    2018    0
# 9   9    2018    0
# 10 10    2018    0
# 11 11    2018    0
# 12 12    2018    0

# %%
tab_201804 <- tab %>% filter(year==2018, month==4) %>% group_by(day,month,year) %>% summarise(sum(deaths))

# %%
names(tab_201805) <- c('day', 'month', 'year', 'deaths')
names(tab_201804) <- c('day', 'month', 'year', 'deaths')

# %%
tab_201805 %>% ggplot(aes(day,deaths)) + geom_line() + geom_point()
# Out:
# plot without title

# %%
tab_201804 %>% ggplot(aes(day,deaths)) + geom_line() + geom_point()
# Out:
# plot without title

# %%
tab <- tab %>% filter(date<as.Date("2018-05-01")) #%>% group_by(year) %>% summarise(sum(deaths))

# %%
tab %>% ggplot(aes(date,deaths, col=year)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# >5. Remake the plot above but this time plot deaths against the day of the year, e.g. Jan 12, 2016 and Jan 12, 2017 are both day 12. Use color to denote the different years. Hint: use the __lubridate__ function `yday`.

# %%
tab <- tab %>% mutate(day_of_year = yday(date))

# %%
tab %>% head
# Out:
#   day month year deaths date       day_of_year
# 1 1   1     2015 107    2015-01-01 1
# 2 2   1     2015 101    2015-01-02 2
# 3 3   1     2015  78    2015-01-03 3
# 4 4   1     2015 121    2015-01-04 4
# 5 5   1     2015  99    2015-01-05 5
# 6 6   1     2015 104    2015-01-06 6

# %%
tab %>% filter(year!=2018) %>% ggplot(aes(day_of_year,deaths,col=year)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# >6. Remake the plot above but, this time, use two different colors for before and after September 20, 2017.

# %%
tab <- tab %>% mutate(colorcode = case_when(date >= '2017-09-20' ~ 1,TRUE ~ 0))

# %%
tab %>% filter(date >= '2017-08-01' & date < '2018-01-01') %>% ggplot(aes(date,deaths,col=colorcode)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# >7. Advanced: remake the plot above, but this time show the month in the x-axis. Hint: create a variable with the date for a given year. Then use the `scale_x_date` function to show just the months.

# %%
?scale_x_date

# %%
tab %>% filter(date >= '2017-06-01' & date < '2018-01-01') %>% ggplot(aes(date,deaths,col=colorcode)) + geom_point() + scale_x_date(date_breaks = "1 month", date_labels = "%b")
# Out:
# plot without title

# %% [markdown]
# >8. Remake the deaths versus day but with weekly averages. Hint: use the function `round_date`.

# %%
tab %>% mutate(round_week = round_date(tab$date,unit="week"))
# Out:
#      day month year deaths date       day_of_year colorcode round_week
# 1     1  1     2015 107    2015-01-01  1          0         2015-01-04
# 2     2  1     2015 101    2015-01-02  2          0         2015-01-04
# 3     3  1     2015  78    2015-01-03  3          0         2015-01-04
# 4     4  1     2015 121    2015-01-04  4          0         2015-01-04
# 5     5  1     2015  99    2015-01-05  5          0         2015-01-04
# 6     6  1     2015 104    2015-01-06  6          0         2015-01-04
# 7     7  1     2015  79    2015-01-07  7          0         2015-01-04
# 8     8  1     2015  73    2015-01-08  8          0         2015-01-11
# 9     9  1     2015  90    2015-01-09  9          0         2015-01-11
# 10   10  1     2015  75    2015-01-10 10          0         2015-01-11
# 11   11  1     2015  88    2015-01-11 11          0         2015-01-11
# 12   12  1     2015  85    2015-01-12 12          0         2015-01-11
# 13   13  1     2015  74    2015-01-13 13          0         2015-01-11
# 14   14  1     2015  98    2015-01-14 14          0         2015-01-11
# 15   15  1     2015  88    2015-01-15 15          0         2015-01-18
# 16   16  1     2015 111    2015-01-16 16          0         2015-01-18
# 17   17  1     2015  92    2015-01-17 17          0         2015-01-18
# 18   18  1     2015  90    2015-01-18 18          0         2015-01-18
# 19   19  1     2015 101    2015-01-19 19          0         2015-01-18
# 20   20  1     2015  98    2015-01-20 20          0         2015-01-18
# 21   21  1     2015 105    2015-01-21 21          0         2015-01-18
# 22   22  1     2015  71    2015-01-22 22          0         2015-01-25
# 23   23  1     2015  82    2015-01-23 23          0         2015-01-25
# 24   24  1     2015  84    2015-01-24 24          0         2015-01-25
# 25   25  1     2015  83    2015-01-25 25          0         2015-01-25
# 26   26  1     2015  83    2015-01-26 26          0         2015-01-25
# 27   27  1     2015  73    2015-01-27 27          0         2015-01-25
# 28   28  1     2015  87    2015-01-28 28          0         2015-01-25
# 29   29  1     2015  73    2015-01-29 29          0         2015-02-01
# 30   30  1     2015  78    2015-01-30 30          0         2015-02-01
# ⋮    ⋮   ⋮     ⋮    ⋮      ⋮          ⋮           ⋮         ⋮
# 1174  1  12    2017  91    2017-12-01 335         1         2017-12-03
# 1175  2  12    2017  88    2017-12-02 336         1         2017-12-03
# 1176  3  12    2017  80    2017-12-03 337         1         2017-12-03
# 1177  4  12    2017 100    2017-12-04 338         1         2017-12-03
# 1178  5  12    2017  81    2017-12-05 339         1         2017-12-03
# 1179  6  12    2017  85    2017-12-06 340         1         2017-12-03
# 1180  7  12    2017  91    2017-12-07 341         1         2017-12-10
# 1181  8  12    2017  93    2017-12-08 342         1         2017-12-10
# 1182  9  12    2017  87    2017-12-09 343         1         2017-12-10
# 1183 10  12    2017  93    2017-12-10 344         1         2017-12-10
# 1184 11  12    2017  98    2017-12-11 345         1         2017-12-10
# 1185 12  12    2017  71    2017-12-12 346         1         2017-12-10
# 1186 13  12    2017 101    2017-12-13 347         1         2017-12-10
# 1187 14  12    2017 107    2017-12-14 348         1         2017-12-17
# 1188 15  12    2017  88    2017-12-15 349         1         2017-12-17
# 1189 16  12    2017  94    2017-12-16 350         1         2017-12-17
# 1190 17  12    2017  92    2017-12-17 351         1         2017-12-17
# 1191 19  12    2017  82    2017-12-19 353         1         2017-12-17
# 1192 20  12    2017  76    2017-12-20 354         1         2017-12-17
# 1193 21  12    2017  95    2017-12-21 355         1         2017-12-24
# 1194 22  12    2017 105    2017-12-22 356         1         2017-12-24
# 1195 23  12    2017 106    2017-12-23 357         1         2017-12-24
# 1196 24  12    2017  80    2017-12-24 358         1         2017-12-24
# 1197 25  12    2017  79    2017-12-25 359         1         2017-12-24
# 1198 26  12    2017 103    2017-12-26 360         1         2017-12-24
# 1199 27  12    2017  95    2017-12-27 361         1         2017-12-24
# 1200 28  12    2017  93    2017-12-28 362         1         2017-12-31
# 1201 29  12    2017  83    2017-12-29 363         1         2017-12-31
# 1202 30  12    2017  87    2017-12-30 364         1         2017-12-31
# 1203 31  12    2017 102    2017-12-31 365         1         2017-12-31

# %%
x <- ymd_hms("2019-02-04 12:01:59.23")

# %%
round_date(x, "week")
# Out:
# [1] "2009-08-02 UTC"

# %% [markdown]
# >9. Remake the plot but with monthly averages. Hint: use the function `round_date` again.
